# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshsrivi/BITS/blob/main/DVI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation (DSECL ZG555))<br>
# First Semester, 2021-22
# </center></h1>
#
# <h2><center>Assignment 2 – PS3 [Weightage 13%]</center></h2>

# %% [markdown]
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#   <li>Submit only the .IPYNB file. Intermediate files to be attached as mentioned in (2).</li>
#      <li><b><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready.Most effective visuals would fetch maximum credits</div></b></li>
#     <li><b><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></b></li>
# </ol>

# %% [markdown]
# <h3>Objective</h3>
# <h4>What are the features that have the most impact on the car price?</h4>

# %% [markdown]
# ##  Download and Prep the Data: 1 Mark

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
df = pd.read_csv('dvi-a2-ps3-data.csv')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=object)
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# <h4> Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.<br>
# Write down your observations in a markdown cell below. <h4>

# %%
features = list(['bore', 'stroke', 'compression-ratio', 'horsepower'])
df[features].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.heatmap(df[features].corr(), annot=True)

# %% [markdown]
# ### Observations
#
# From the correlation matrix we can see that a positive correlation exists between bore,compression-ratio and horsepower.
# We can also see that a negative correlation exists between stroke & bore and compression ratio & horse power.

# %% [markdown]
# # Visualisation Questions - 2X5 = 10 Marks

# %% [markdown]
# ### Question 1
# <h4>What kind of a correlation exists between<br><br>
#     a."engine-size" and "price"<br><br>
#     b."highway-mpg" and "price"<br><br>
#     c."peak-rpm" and "price"<br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.You obseravtaion about the relationship. Which among engine-size, highway-mpg and peak-rpm is a potential predictor variable of price.<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
df_corr_1 = df[['engine-size', 'price']]
df_corr_1.head()
# Out:
#    engine-size    price
# 0          130  13495.0
# 1          130  16500.0
# 2          152  16500.0
# 3          109  13950.0
# 4          136  17450.0

# %%
df_corr_1.plot(kind='scatter', x='engine-size', y='price', figsize=(10, 6), color='green')

plt.title('Engine-size Vs Price')
plt.xlabel('Engine-size')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# From the plot we can see that the price increses w.r.t the increase in Engine-size. Hence a positive correlation is seen here

# %%
df_corr_2 = df[["highway-mpg", "price"]]
df_corr_2.head()
# Out:
#    highway-mpg    price
# 0           27  13495.0
# 1           27  16500.0
# 2           26  16500.0
# 3           30  13950.0
# 4           22  17450.0

# %%
df_corr_2.plot(kind='scatter', x='highway-mpg', y='price', figsize=(10, 6), color='red')

plt.title('Highway-mpg Vs Price')
plt.xlabel('Highway-mpg')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# From the plot we can see that the price decreases with incresae in highway mpg. Hence a negative correlation exists between these two variables

# %%
df_corr_3 = df[["peak-rpm", "price"]]
df_corr_3.head()
# Out:
#    peak-rpm    price
# 0    5000.0  13495.0
# 1    5000.0  16500.0
# 2    5000.0  16500.0
# 3    5500.0  13950.0
# 4    5500.0  17450.0

# %%
df_corr_3.plot(kind='scatter', x='peak-rpm', y='price', figsize=(10, 6), color='darkblue')

plt.title('peak-rpm Vs Price')
plt.xlabel('peak-rpm')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# There is no positive or negative trend seen in the plot. Hence no correlation exists between the two variables.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))
sns.heatmap(df[['engine-size', 'price']].corr(), ax=ax1, annot=True, vmin=-1, vmax=1)
sns.heatmap(df[["highway-mpg", "price"]].corr(), ax=ax2, annot=True, vmin=-1, vmax=1)
sns.heatmap(df[["peak-rpm", "price"]].corr(), ax=ax3, annot=True, vmin=-1, vmax=1)

plt.show()

# %% [markdown]
# ### Observations
#
# 1. Among engine-size, highway-mpg and peak-rpm, engine-size and highway-mpg are the potential predictor variable of price as they are highly correlated to price.
# 2. Pre-attentive attributes used are:
#     1. Spatial Positioning: in scatter plot to determine weather there is any correlation
#     2. Color: in heatmap to determine how much features are correlated to price
# 3. Gestalt principles used are:
#     1. Proximity: Through the position of near points in scatter plot, we can say in which direction points are going
#     2. Similarity:  Through the colour we can tell that less correlated features are of pink shade, but correlated features are more white or brown

# %% [markdown]
# ### Question 2
# <h4> Use boxplots to visualise the relationship between<br><br>
#     a."body-style" and "price". <br><br>
#     b."engine-location" and "price" <br><br>
#     c."drive-wheels"and "price" <br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.Your observataion about the relationship .Which among engine-location ,body-style and drive-wheels is a potential predictor variable of price<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 15))
sns.set_theme(style='whitegrid')
sns.boxplot(x='body-style', y='price', data=df, ax=ax1)
sns.boxplot(x='engine-location', y='price', data=df, ax=ax2)
sns.boxplot(x='drive-wheels', y='price', data=df, ax=ax3)

plt.show()

# %% [markdown]
# ### Observations
#
# 1. Relationship between:
#     1. body-style and price: `convertible` and `hardtop` style cars are on average more expensive than `hatchback`, `sedan` and `wagon`, these three are similarly priced with `hatchback` being the cheapest.
#     2. engine-location and price: other than outliers in `front`, cars with `rear` engine are always more expensive `front` engine
#     3. drive-wheels and price: `rwd` are generally more expensive the `fwd` and `4wd`, both of which are similarly priced but `fwd` has more range than `4wd`
# 2. Pre-attentive attributes used are:
#     1. Form: size of the box determines the range of price from 1st quartile to 3rd quartile. Dots denotes the outlier.
#     2. Spatial Positioning: position of box denotes the price in respective quartile, position of dots shows how big of outlier they are and their price.
# 3. Gestalt principles used are:
#     1. Proximity: Through the position of position of box, whisker and dots we can determine their price and where they stand compared to other categories
#     2. Figure and Ground: Box plots are the figures and grid lines are the background helping in comparing the categories.

# %% [markdown]
# ### Question 3
# <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all continuous variables.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
cont = df.select_dtypes("number")  #Here we are storing the continuous variables in the variable 'cont'
cont.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# ...

# %%
cont.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
fig, axis = plt.subplots(len(cont.columns), 1, figsize=(10, 75))
for i in range(len(cont.columns)):
    sns.histplot(x=cont.columns[i], data=cont, ax=axis[i])

plt.show()

# %% [markdown]
# ### Observations
#
# 1. Through the visualization we can see the distribution of number of cars with respect to each attributes
# 2. We have chosen histogram because it enables us to visualize the underlying distribution pattern of our data
# 3. Pre-attentive attributes used are:
#     1. Form: length of the box determines the count of cars in that range of attribute.
#     2. Spatial Positioning: position of box denotes the range that the box represents within the attribute.
# 4. Gestalt principles used are:
#     1. Proximity: Through the position of position of box we can determine the range of the attribute.
#     2. Figure and Ground: Boxs are the figures and grid lines are the background helping us to compare the attribute range.

# %% [markdown]
#   ### Question 4
#   <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all variables of type 'Object'.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
catg = df.select_dtypes("object")  #Here we are storing the categorical variable in the variable 'catg'
catg.head()
# Out:
#           make aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero        std          two  convertible          rwd
# 1  alfa-romero        std          two  convertible          rwd
# 2  alfa-romero        std          two    hatchback          rwd
# 3         audi        std         four        sedan          fwd
# 4         audi        std         four        sedan          4wd
#
#   engine-location engine-type num-of-cylinders fuel-system horsepower-binned
# 0           front        dohc             four        mpfi            Medium
# 1           front        dohc             four        mpfi            Medium
# 2           front        ohcv              six        mpfi            Medium
# 3           front         ohc             four        mpfi            Medium
# 4           front         ohc             five        mpfi            Medium

# %%
fig, axis = plt.subplots(len(catg.columns), 1, figsize=(20, 50))
for i in range(len(catg.columns)):
    sns.histplot(x=catg.columns[i], data=catg, ax=axis[i])

plt.show()

# %% [markdown]
# ### Observations
#
# 1. Through the visualization we can see the distribution of number of cars with respect to each attributes
# 2. We have chosen histogram because it enables us to visualize the underlying distribution pattern of our data
# 3. Pre-attentive attributes used are:
#     1. Form: length of the box determines the count of cars in that category.
#     2. Spatial Positioning: position of box denotes the category that the box represents of the attribute.
# 4. Gestalt principles used are:
#     1. Proximity: Through the position of position of box we can determine the category of the attribute.
#     2. Figure and Ground: Boxs are the figures and grid lines are the background helping us to compare the attribute range.

# %% [markdown]
# ### Question 5
# <h4> Use a single heat map to visualize the relationship between Body Style and Drive-wheel vs Price.</h4>
# <h4>Perform the data preprocessing required.<br>
#
# <p>The heatmap should plot  the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.</p>
#
# The plot should have labels for x axis and y axis<br>
# Write down your observations in a markdown cell below the visual</h4>
#
# 1.Mention the pre-attentive attributes used.(atleast 2)<br>
# 2.Mention the gestalt principles used.(atleast 2)<br>

# %%
sns.set(font_scale=1.4)

body_style_df = df.pivot_table(values='price', index='body-style', aggfunc=np.mean).sort_values(by='price', axis=0, ascending=False)
drive_wheel_df = df.pivot_table(values='price', index='drive-wheels', aggfunc=np.mean).sort_values(by='price', axis=0, ascending=False)
fig, axis = plt.subplots(1, 2, figsize=(15, 10))
sns.heatmap(body_style_df, vmin=23000, vmax=9000, annot=True, ax=axis[0], annot_kws={"fontsize": 20})
sns.heatmap(drive_wheel_df, vmin=23000, vmax=9000, annot=True, ax=axis[1], annot_kws={"fontsize": 20})

plt.show()

# %%
df_heatmap = df.pivot_table(values='price', index='body-style', columns='drive-wheels', aggfunc=np.mean)
fig, axis = plt.subplots(figsize=(15, 10))
sns.heatmap(df_heatmap, annot=True, ax=axis, annot_kws={"fontsize": 20}, cbar_kws={'label': 'price'})

plt.show()

# %% [markdown]
# ### Observations
#
# 1. Through above visuals we can conclude that:
#     1. `convertible` & `hardtop` in body-style and `rwd` in drive-wheels leads to higher price so combination of these 2 will result in most expensive cars(we can confirm this from second visuals)
#     2. `4wd` & `fwd` in drive-wheels leads to cheaper priced cars
# 2. Pre-attentive attributes used are:
#     1. Color: denotes how much the feature category contributes to price increase
#     2. Spatial Positioning: visuals have been sorted to how higher priced categories over lower priced categories.
# 3. Gestalt principles used are:
#     1. Similarity:  Through the colour we can tell that lesser priced categories are of blue shade, but higher priced categories are more brown
#     2. Similarity: Thorough similar colours between categories of body-style and drive-wheels we can tell which categories are similarly priced.

# %% [markdown]
# # Group's choice-2 Marks
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question,in a coding cell,write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did. <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ### Question
#
# Perform a correlation analysis on continuous attributes.

# %%
fig, axis = plt.subplots(figsize=(20, 20))
sns.heatmap(cont.corr(), annot=True, ax=axis)

# %% [markdown]
# ### Observations
#
# 1. Findings:
#     1. `wheel-base` has high positive correlation with `length`, `width` & `curb-weight`
#     2. `length` has high positive correlation with `curb-weight` and negative correlation with `highway-mpg`
#     3. `width` has high positive correlation with `curb-weight` & `engine-size`
#     4. `engine-size` has high positive correlation with `horsepower`
#     5. `curb-weight` has high positive correlation with `engine-size` & `horsepower` and negative correlation with `highway-mpg`
#     6. `horsepower` has negative correlation with `city-mpg` & `highway-mpg`
#     7. `diesel` and `gas` are fully negative correlated.
#     8. `compression-ratio` has high positive correlation with `diesel` and high negative correlation with `gas`
#     9. `city-mpg` and `highway-mpg` are highly positive correlated
# 2. Reason for selecting the chart type
#     1. heatmap is graphical representation of correlation matrix representing correlation between different variables
#     2. Through use of colours it becomes very intuitive to notice the correlated attributes
# 3. Pre-attentive attributes used are:
#     1. Color: darker shade denotes higher positive correlation
#     2. Color: lighter shade denotes higher negative correlation
# 4. Gestalt principles used are:
#     1. Similarity: Through the colour we can tell that positive correlated attributes are more brown.
#     2. Similarity: Through the colour we can tell that negative correlated attributes are more blue.
